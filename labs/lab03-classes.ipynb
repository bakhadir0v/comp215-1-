# %% [markdown]
# <a href="https://colab.research.google.com/github/bakhadir0v/comp215-1-/blob/main/labs/lab03-classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 3
# ----------------
# #### Name(s):Ata
# #### Date:23.01.2025
#
# By the end of this lab you should be able to:
#   * use a `class` to organize related data and functions
#   * identify a `record` as a related collection of data, with fields for each data value
#
# During this lab, you will be introduced to the following:
#   * the `@dataclass` decorator to simplify class definition for classes that primarily encapsulate a data structure.
#   * the `@classmethod` decorator to create 'object factories'.
#   * plotting frequency distributions in `matplotlib`

# %% [markdown]
# ## Near Earth Objects (with classes)
#
# We'll continue working with Near Earth Object data using NASA's API: https://api.nasa.gov/.  In this lab we will define an Asteroid class to help us structure the data for easier data analysis.  Here's a brief review from Lab 2 on how to use the API.

# %%
# import necessary modules
import datetime, json, requests
from dataclasses import dataclass
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Review: make an API query
#
# Here's a query that gets the record for a single NEO that recently passed by.  Read these functions carefully to be sure you know what they are returning.  Note the nested for loop structure in the return statement of the `get_neos` function - be sure to understand what it is doing.  You might want to add some more `pprint` statements to be sure you understand the data structures.

# %%
API_KEY = '9FJ4JxFTJsq7dEB6zpPemkbnZlCdXZyh6XbTnfrG'  # substitute your API key here

def get_neos(start_date):
    """ Return a list of NEO for the week starting at start_date """
    url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={start_date}&api_key={API_KEY}'
    # Fetch last week's NEO feed
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)
    print(f'{data["element_count"]} Near Earth Objects found for week of {start_date}')
    return [neo for dated_records in data['near_earth_objects'].values() for neo in dated_records ]

def get_neo(id):
    """ Return a NEO record for the given id """
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    return json.loads(response.text)

week_start = '2023-09-15'
neos = get_neos(week_start)
assert len(neos) > 0, f'Oh oh!  No NEOs found for {week_start}'
neo = get_neo(neos[-1]['id'])  # get the very latest NEO
pprint(neo)
# Out:
# 217 Near Earth Objects found for week of 2023-09-15
# {'absolute_magnitude_h': 21.29,
#  'close_approach_data': [{'close_approach_date': '1906-03-24',
#                           'close_approach_date_full': '1906-Mar-24 21:18',
#                           'epoch_date_close_approach': -2012524920000,
#                           'miss_distance': {'astronomical': '0.092739936',
#                                             'kilometers': '13873696.88953632',
#                                             'lunar': '36.075835104',
#                                             'miles': '8620715.499268416'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '73505.6050553395',
#                                                 'kilometers_per_second': '20.4182236265',
#                                                 'miles_per_hour': '45673.5244300803'}},
#                          {'close_approach_date': '1913-12-03',
#                           'close_approach_date_full': '1913-Dec-03 22:29',
#                           'epoch_date_close_approach': -1769650260000,
#                           'miss_distance': {'astronomical': '0.4657951676',
#                                             'kilometers': '69681964.929253012',
#                                             'lunar': '181.1943201964',
#                                             'miles': '43298365.2351630856'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '91876.6881651236',
#                                                 'kilometers_per_second': '25.5213022681',
#                                                 'miles_per_hour': '57088.6010434903'}},
#                          {'close_approach_date': '1914-10-31',
#                           'close_approach_date_full': '1914-Oct-31 13:51',
#                           'epoch_date_close_approach': -1740996540000,
#                           'miss_distance': {'astronomical': '0.0401677612',
#                                             'kilometers': '6009011.518188644',
#                                             'lunar': '15.6252591068',
#                                             'miles': '3733826.6175615272'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '67490.6899813193',
#                                                 'kilometers_per_second': '18.7474138837',
#                                                 'miles_per_hour': '41936.0901164481'}},
#                          {'close_approach_date': '1914-11-14',
#                           'close_approach_date_full': '1914-Nov-14 05:44',
#                           'epoch_date_close_approach': -1739816160000,
#                           'miss_distance': {'astronomical': '0.2706726363',
#                                             'kilometers': '40492049.857764681',
#                                             'lunar': '105.2916555207',
#                                             'miles': '25160593.0694113578'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '76464.3262422168',
#                                                 'kilometers_per_second': '21.2400906228',
#                                                 'miles_per_hour': '47511.9587142263'}},
#                          {'close_approach_date': '1915-10-22',
#                           'close_approach_date_full': '1915-Oct-22 21:21',
#                           'epoch_date_close_approach': -1710211140000,
#                           'miss_distance': {'astronomical': '0.2221129559',
#                                             'kilometers': '33227625.102043933',
#                                             'lunar': '86.4019398451',
#                                             'miles': '20646688.8387269554'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69376.7940606155',
#                                                 'kilometers_per_second': '19.2713316835',
#                                                 'miles_per_hour': '43108.0418428308'}},
#                          {'close_approach_date': '1916-04-02',
#                           'close_approach_date_full': '1916-Apr-02 17:58',
#                           'epoch_date_close_approach': -1696140120000,
#                           'miss_distance': {'astronomical': '0.4780646058',
#                                             'kilometers': '71517446.750069646',
#                                             'lunar': '185.9671316562',
#                                             'miles': '44438880.7522112748'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '56789.8626507775',
#                                                 'kilometers_per_second': '15.7749618474',
#                                                 'miles_per_hour': '35287.0121565345'}},
#                          {'close_approach_date': '1916-09-25',
#                           'close_approach_date_full': '1916-Sep-25 16:47',
#                           'epoch_date_close_approach': -1680937980000,
#                           'miss_distance': {'astronomical': '0.3603059789',
#                                             'kilometers': '53901006.991704943',
#                                             'lunar': '140.1590257921',
#                                             'miles': '33492532.6752684934'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68689.0172196544',
#                                                 'kilometers_per_second': '19.080282561',
#                                                 'miles_per_hour': '42680.6840607347'}},
#                          {'close_approach_date': '1917-04-17',
#                           'close_approach_date_full': '1917-Apr-17 02:09',
#                           'epoch_date_close_approach': -1663365060000,
#                           'miss_distance': {'astronomical': '0.2835592468',
#                                             'kilometers': '42419859.340084316',
#                                             'lunar': '110.3045470052',
#                                             'miles': '26358478.3350469208'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55190.2826082323',
#                                                 'kilometers_per_second': '15.3306340578',
#                                                 'miles_per_hour': '34293.0953239874'}},
#                          {'close_approach_date': '1918-04-22',
#                           'close_approach_date_full': '1918-Apr-22 07:23',
#                           'epoch_date_close_approach': -1631378220000,
#                           'miss_distance': {'astronomical': '0.0934557176',
#                                             'kilometers': '13980776.292281512',
#                                             'lunar': '36.3542741464',
#                                             'miles': '8687251.5548163856'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '58392.8984123528',
#                                                 'kilometers_per_second': '16.220249559',
#                                                 'miles_per_hour': '36283.0762384978'}},
#                          {'close_approach_date': '1919-04-20',
#                           'close_approach_date_full': '1919-Apr-20 05:43',
#                           'epoch_date_close_approach': -1600021020000,
#                           'miss_distance': {'astronomical': '0.2229551181',
#                                             'kilometers': '33353610.773358447',
#                                             'lunar': '86.7295409409',
#                                             'miles': '20724972.7048106886'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71975.8688246086',
#                                                 'kilometers_per_second': '19.9932968957',
#                                                 'miles_per_hour': '44723.0058260464'}},
#                          {'close_approach_date': '1920-04-12',
#                           'close_approach_date_full': '1920-Apr-12 20:34',
#                           'epoch_date_close_approach': -1569036360000,
#                           'miss_distance': {'astronomical': '0.4643465751',
#                                             'kilometers': '69465258.576755037',
#                                             'lunar': '180.6308177139',
#                                             'miles': '43163710.1517600306'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '93001.4438139104',
#                                                 'kilometers_per_second': '25.8337343928',
#                                                 'miles_per_hour': '57787.480463149'}},
#                          {'close_approach_date': '1923-06-09',
#                           'close_approach_date_full': '1923-Jun-09 01:41',
#                           'epoch_date_close_approach': -1469485140000,
#                           'miss_distance': {'astronomical': '0.1338821997',
#                                             'kilometers': '20028491.906034639',
#                                             'lunar': '52.0801756833',
#                                             'miles': '12445127.7821664582'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '65157.2951232895',
#                                                 'kilometers_per_second': '18.0992486454',
#                                                 'miles_per_hour': '40486.2092948018'}},
#                          {'close_approach_date': '1935-11-21',
#                           'close_approach_date_full': '1935-Nov-21 06:18',
#                           'epoch_date_close_approach': -1076521320000,
#                           'miss_distance': {'astronomical': '0.3263124672',
#                                             'kilometers': '48815650.047564864',
#                                             'lunar': '126.9355497408',
#                                             'miles': '30332638.3964245632'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '80619.676836332',
#                                                 'kilometers_per_second': '22.3943546768',
#                                                 'miles_per_hour': '50093.931976442'}},
#                          {'close_approach_date': '1936-10-29',
#                           'close_approach_date_full': '1936-Oct-29 19:27',
#                           'epoch_date_close_approach': -1046838780000,
#                           'miss_distance': {'astronomical': '0.2106940411',
#                                             'kilometers': '31519379.770252457',
#                                             'lunar': '81.9599819879',
#                                             'miles': '19585234.4098476266'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70703.6938350649',
#                                                 'kilometers_per_second': '19.6399149542',
#                                                 'miles_per_hour': '43932.5257610158'}},
#                          {'close_approach_date': '1937-10-05',
#                           'close_approach_date_full': '1937-Oct-05 02:30',
#                           'epoch_date_close_approach': -1017437400000,
#                           'miss_distance': {'astronomical': '0.3073619129',
#                                             'kilometers': '45980687.488965523',
#                                             'lunar': '119.5637841181',
#                                             'miles': '28571074.3473212974'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68662.3466341202',
#                                                 'kilometers_per_second': '19.072874065',
#                                                 'miles_per_hour': '42664.1119960732'}},
#                          {'close_approach_date': '1938-04-13',
#                           'close_approach_date_full': '1938-Apr-13 23:56',
#                           'epoch_date_close_approach': -1000944240000,
#                           'miss_distance': {'astronomical': '0.3490658097',
#                                             'kilometers': '52219501.620945339',
#                                             'lunar': '135.7865999733',
#                                             'miles': '32447693.6877061182'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55610.1024337836',
#                                                 'kilometers_per_second': '15.4472506761',
#                                                 'miles_per_hour': '34553.9550372585'}},
#                          {'close_approach_date': '1938-09-03',
#                           'close_approach_date_full': '1938-Sep-03 14:45',
#                           'epoch_date_close_approach': -988622100000,
#                           'miss_distance': {'astronomical': '0.4715234831',
#                                             'kilometers': '70538908.726740997',
#                                             'lunar': '183.4226349259',
#                                             'miles': '43830845.4194878786'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65901.001173241',
#                                                 'kilometers_per_second': '18.3058336592',
#                                                 'miles_per_hour': '40948.3193123396'}},
#                          {'close_approach_date': '1939-04-21',
#                           'close_approach_date_full': '1939-Apr-21 22:02',
#                           'epoch_date_close_approach': -968723880000,
#                           'miss_distance': {'astronomical': '0.1437114935',
#                                             'kilometers': '21498933.322118845',
#                                             'lunar': '55.9037709715',
#                                             'miles': '13358817.709756261'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '56357.3693764901',
#                                                 'kilometers_per_second': '15.6548248268',
#                                                 'miles_per_hour': '35018.2776550752'}},
#                          {'close_approach_date': '1940-04-20',
#                           'close_approach_date_full': '1940-Apr-20 21:33',
#                           'epoch_date_close_approach': -937189620000,
#                           'miss_distance': {'astronomical': '0.1526417022',
#                                             'kilometers': '22834873.522294314',
#                                             'lunar': '59.3776221558',
#                                             'miles': '14188932.4572129732'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66587.5321693535',
#                                                 'kilometers_per_second': '18.4965367137',
#                                                 'miles_per_hour': '41374.9029748963'}},
#                          {'close_approach_date': '1941-04-15',
#                           'close_approach_date_full': '1941-Apr-15 12:48',
#                           'epoch_date_close_approach': -906117120000,
#                           'miss_distance': {'astronomical': '0.3882138733',
#                                             'kilometers': '58075968.550129871',
#                                             'lunar': '151.0151967137',
#                                             'miles': '36086733.4929833798'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '85912.7948145184',
#                                                 'kilometers_per_second': '23.8646652263',
#                                                 'miles_per_hour': '53382.86964461'}},
#                          {'close_approach_date': '1942-07-11',
#                           'close_approach_date_full': '1942-Jul-11 23:14',
#                           'epoch_date_close_approach': -867026760000,
#                           'miss_distance': {'astronomical': '0.1167015976',
#                                             'kilometers': '17458310.426557112',
#                                             'lunar': '45.3969214664',
#                                             'miles': '10848091.0663956656'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '75535.1429615759',
#                                                 'kilometers_per_second': '20.981984156',
#                                                 'miles_per_hour': '46934.6003585414'}},
#                          {'close_approach_date': '1951-02-17',
#                           'close_approach_date_full': '1951-Feb-17 11:45',
#                           'epoch_date_close_approach': -595512900000,
#                           'miss_distance': {'astronomical': '0.0374810558',
#                                             'kilometers': '5607086.113031146',
#                                             'lunar': '14.5801307062',
#                                             'miles': '3484081.7516199748'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '68460.0593727546',
#                                                 'kilometers_per_second': '19.0166831591',
#                                                 'miles_per_hour': '42538.4185585874'}},
#                          {'close_approach_date': '1956-11-28',
#                           'close_approach_date_full': '1956-Nov-28 05:49',
#                           'epoch_date_close_approach': -413143860000,
#                           'miss_distance': {'astronomical': '0.4032898737',
#                                             'kilometers': '60331306.098089019',
#                                             'lunar': '156.8797608693',
#                                             'miles': '37488135.2614217022'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '86612.2993039126',
#                                                 'kilometers_per_second': '24.0589720289',
#                                                 'miles_per_hour': '53817.5145313672'}},
#                          {'close_approach_date': '1957-11-07',
#                           'close_approach_date_full': '1957-Nov-07 22:03',
#                           'epoch_date_close_approach': -383363820000,
#                           'miss_distance': {'astronomical': '0.2331993264',
#                                             'kilometers': '34886122.514874768',
#                                             'lunar': '90.7145379696',
#                                             'miles': '21677231.3441690784'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '73520.414522879',
#                                                 'kilometers_per_second': '20.4223373675',
#                                                 'miles_per_hour': '45682.7264572856'}},
#                          {'close_approach_date': '1958-10-15',
#                           'close_approach_date_full': '1958-Oct-15 19:28',
#                           'epoch_date_close_approach': -353824320000,
#                           'miss_distance': {'astronomical': '0.2503816871',
#                                             'kilometers': '37456567.077166477',
#                                             'lunar': '97.3984762819',
#                                             'miles': '23274431.5320203026'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68822.3487272303',
#                                                 'kilometers_per_second': '19.1173190909',
#                                                 'miles_per_hour': '42763.5310744282'}},
#                          {'close_approach_date': '1959-04-08',
#                           'close_approach_date_full': '1959-Apr-08 16:30',
#                           'epoch_date_close_approach': -338715000000,
#                           'miss_distance': {'astronomical': '0.4259975958',
#                                             'kilometers': '63728332.956800946',
#                                             'lunar': '165.7130647662',
#                                             'miles': '39598949.8716512148'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '56441.0934735242',
#                                                 'kilometers_per_second': '15.6780815204',
#                                                 'miles_per_hour': '35070.3005530351'}},
#                          {'close_approach_date': '1959-09-18',
#                           'close_approach_date_full': '1959-Sep-18 01:26',
#                           'epoch_date_close_approach': -324686040000,
#                           'miss_distance': {'astronomical': '0.4067826691',
#                                             'kilometers': '60853820.850274817',
#                                             'lunar': '158.2384582799',
#                                             'miles': '37812810.8730217946'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68368.1703494242',
#                                                 'kilometers_per_second': '18.9911584304',
#                                                 'miles_per_hour': '42481.3222929519'}},
#                          {'close_approach_date': '1959-09-26',
#                           'close_approach_date_full': '1959-Sep-26 07:18',
#                           'epoch_date_close_approach': -323973720000,
#                           'miss_distance': {'astronomical': '0.1020490989',
#                                             'kilometers': '15266327.830859343',
#                                             'lunar': '39.6970994721',
#                                             'miles': '9486056.2398232134'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '65324.8298694787',
#                                                 'kilometers_per_second': '18.1457860749',
#                                                 'miles_per_hour': '40590.3088708436'}},
#                          {'close_approach_date': '1960-04-19',
#                           'close_approach_date_full': '1960-Apr-19 05:16',
#                           'epoch_date_close_approach': -306182640000,
#                           'miss_distance': {'astronomical': '0.2245658509',
#                                             'kilometers': '33594572.969377583',
#                                             'lunar': '87.3561160001',
#                                             'miles': '20874699.6704853254'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55224.3173247407',
#                                                 'kilometers_per_second': '15.3400881458',
#                                                 'miles_per_hour': '34314.2431732535'}},
#                          {'close_approach_date': '1961-04-22',
#                           'close_approach_date_full': '1961-Apr-22 03:31',
#                           'epoch_date_close_approach': -274393740000,
#                           'miss_distance': {'astronomical': '0.0893406031',
#                                             'kilometers': '13365163.928275397',
#                                             'lunar': '34.7534946059',
#                                             'miles': '8304727.7696865986'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '61187.9845999831',
#                                                 'kilometers_per_second': '16.9966623889',
#                                                 'miles_per_hour': '38019.8340976951'}},
#                          {'close_approach_date': '1962-04-18',
#                           'close_approach_date_full': '1962-Apr-18 13:38',
#                           'epoch_date_close_approach': -243166920000,
#                           'miss_distance': {'astronomical': '0.2907708293',
#                                             'kilometers': '43498696.721413591',
#                                             'lunar': '113.1098525977',
#                                             'miles': '27028836.7988699158'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77383.6611534976',
#                                                 'kilometers_per_second': '21.4954614315',
#                                                 'miles_per_hour': '48083.197676183'}},
#                          {'close_approach_date': '1977-12-04',
#                           'close_approach_date_full': '1977-Dec-04 21:44',
#                           'epoch_date_close_approach': 250119840000,
#                           'miss_distance': {'astronomical': '0.4745449892',
#                                             'kilometers': '70990919.603493004',
#                                             'lunar': '184.5980007988',
#                                             'miles': '44111711.9543472952'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '92510.9221951555',
#                                                 'kilometers_per_second': '25.6974783875',
#                                                 'miles_per_hour': '57482.6894050954'}},
#                          {'close_approach_date': '1978-10-29',
#                           'close_approach_date_full': '1978-Oct-29 08:52',
#                           'epoch_date_close_approach': 278499120000,
#                           'miss_distance': {'astronomical': '0.1499419312',
#                                             'kilometers': '22430993.531206544',
#                                             'lunar': '58.3274112368',
#                                             'miles': '13937973.0678925472'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '78567.1744018846',
#                                                 'kilometers_per_second': '21.8242151116',
#                                                 'miles_per_hour': '48818.5867832154'}},
#                          {'close_approach_date': '1978-11-15',
#                           'close_approach_date_full': '1978-Nov-15 03:28',
#                           'epoch_date_close_approach': 279948480000,
#                           'miss_distance': {'astronomical': '0.2758806373',
#                                             'kilometers': '41271155.714322551',
#                                             'lunar': '107.3175679097',
#                                             'miles': '25644707.0000151638'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '76824.7408698887',
#                                                 'kilometers_per_second': '21.3402057972',
#                                                 'miles_per_hour': '47735.9063477372'}},
#                          {'close_approach_date': '1979-10-23',
#                           'close_approach_date_full': '1979-Oct-23 21:10',
#                           'epoch_date_close_approach': 309561000000,
#                           'miss_distance': {'astronomical': '0.2201046187',
#                                             'kilometers': '32927182.134682169',
#                                             'lunar': '85.6206966743',
#                                             'miles': '20460002.2355811722'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69491.1747800056',
#                                                 'kilometers_per_second': '19.3031041056',
#                                                 'miles_per_hour': '43179.1135737207'}},
#                          {'close_approach_date': '1980-04-02',
#                           'close_approach_date_full': '1980-Apr-02 10:23',
#                           'epoch_date_close_approach': 323518980000,
#                           'miss_distance': {'astronomical': '0.4826493117',
#                                             'kilometers': '72203308.987286079',
#                                             'lunar': '187.7505822513',
#                                             'miles': '44865055.7844187302'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '56780.6433474485',
#                                                 'kilometers_per_second': '15.7724009298',
#                                                 'miles_per_hour': '35281.2836399743'}},
#                          {'close_approach_date': '1980-09-26',
#                           'close_approach_date_full': '1980-Sep-26 20:40',
#                           'epoch_date_close_approach': 338848800000,
#                           'miss_distance': {'astronomical': '0.3545223245',
#                                             'kilometers': '53035784.612648815',
#                                             'lunar': '137.9091842305',
#                                             'miles': '32954908.418891047'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68739.1547946152',
#                                                 'kilometers_per_second': '19.0942096652',
#                                                 'miles_per_hour': '42711.8376000208'}},
#                          {'close_approach_date': '1981-04-16',
#                           'close_approach_date_full': '1981-Apr-16 23:37',
#                           'epoch_date_close_approach': 356312220000,
#                           'miss_distance': {'astronomical': '0.2895403934',
#                                             'kilometers': '43314626.131602058',
#                                             'lunar': '112.6312130326',
#                                             'miles': '26914460.6380540804'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55201.051277325',
#                                                 'kilometers_per_second': '15.3336253548',
#                                                 'miles_per_hour': '34299.7865561801'}},
#                          {'close_approach_date': '1982-04-22',
#                           'close_approach_date_full': '1982-Apr-22 11:23',
#                           'epoch_date_close_approach': 388322580000,
#                           'miss_distance': {'astronomical': '0.0973091499',
#                                             'kilometers': '14557241.556550713',
#                                             'lunar': '37.8532593111',
#                                             'miles': '9045450.4601293194'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '58198.3670510096',
#                                                 'kilometers_per_second': '16.1662130697',
#                                                 'miles_per_hour': '36162.2020156676'}},
#                          {'close_approach_date': '1983-04-20',
#                           'close_approach_date_full': '1983-Apr-20 15:17',
#                           'epoch_date_close_approach': 419699820000,
#                           'miss_distance': {'astronomical': '0.2161085274',
#                                             'kilometers': '32329375.387876638',
#                                             'lunar': '84.0662171586',
#                                             'miles': '20088542.3479400844'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71348.6083633477',
#                                                 'kilometers_per_second': '19.8190578787',
#                                                 'miles_per_hour': '44333.2505688813'}},
#                          {'close_approach_date': '1984-04-13',
#                           'close_approach_date_full': '1984-Apr-13 08:46',
#                           'epoch_date_close_approach': 450693960000,
#                           'miss_distance': {'astronomical': '0.4567993331',
#                                             'kilometers': '68336207.249180497',
#                                             'lunar': '177.6949405759',
#                                             'miles': '42462150.1885729786'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '92162.7833218992',
#                                                 'kilometers_per_second': '25.600773145',
#                                                 'miles_per_hour': '57266.3694479879'}},
#                          {'close_approach_date': '1987-06-06',
#                           'close_approach_date_full': '1987-Jun-06 15:28',
#                           'epoch_date_close_approach': 549991680000,
#                           'miss_distance': {'astronomical': '0.0503681419',
#                                             'kilometers': '7534966.744097753',
#                                             'lunar': '19.5932071991',
#                                             'miles': '4682011.2270368714'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '70029.7630861298',
#                                                 'kilometers_per_second': '19.4527119684',
#                                                 'miles_per_hour': '43513.7714020455'}},
#                          {'close_approach_date': '1996-01-13',
#                           'close_approach_date_full': '1996-Jan-13 22:50',
#                           'epoch_date_close_approach': 821573400000,
#                           'miss_distance': {'astronomical': '0.0605328524',
#                                             'kilometers': '9055585.784064388',
#                                             'lunar': '23.5472795836',
#                                             'miles': '5626880.0843210344'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '66308.1688783152',
#                                                 'kilometers_per_second': '18.4189357995',
#                                                 'miles_per_hour': '41201.3174899731'}},
#                          {'close_approach_date': '1999-11-24',
#                           'close_approach_date_full': '1999-Nov-24 19:03',
#                           'epoch_date_close_approach': 943470180000,
#                           'miss_distance': {'astronomical': '0.3580001391',
#                                             'kilometers': '53556058.269063717',
#                                             'lunar': '139.2620541099',
#                                             'miles': '33278191.4781526146'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82983.1715970127',
#                                                 'kilometers_per_second': '23.0508809992',
#                                                 'miles_per_hour': '51562.5157070438'}},
#                          {'close_approach_date': '2000-11-02',
#                           'close_approach_date_full': '2000-Nov-02 20:14',
#                           'epoch_date_close_approach': 973196040000,
#                           'miss_distance': {'astronomical': '0.2159745774',
#                                             'kilometers': '32309336.753190138',
#                                             'lunar': '84.0141106086',
#                                             'miles': '20076090.9177263844'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71766.1065476498',
#                                                 'kilometers_per_second': '19.9350295966',
#                                                 'miles_per_hour': '44592.6677045661'}},
#                          {'close_approach_date': '2001-10-09',
#                           'close_approach_date_full': '2001-Oct-09 21:17',
#                           'epoch_date_close_approach': 1002662220000,
#                           'miss_distance': {'astronomical': '0.2809310014',
#                                             'kilometers': '42026679.426407018',
#                                             'lunar': '109.2821595446',
#                                             'miles': '26114167.6655241284'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68698.982838505',
#                                                 'kilometers_per_second': '19.0830507885',
#                                                 'miles_per_hour': '42686.8763087366'}},
#                          {'close_approach_date': '2002-04-11',
#                           'close_approach_date_full': '2002-Apr-11 22:42',
#                           'epoch_date_close_approach': 1018564920000,
#                           'miss_distance': {'astronomical': '0.3819530015',
#                                             'kilometers': '57139355.464506805',
#                                             'lunar': '148.5797175835',
#                                             'miles': '35504749.108551709'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55996.9842759113',
#                                                 'kilometers_per_second': '15.5547178544',
#                                                 'miles_per_hour': '34794.3483685517'}},
#                          {'close_approach_date': '2002-09-10',
#                           'close_approach_date_full': '2002-Sep-10 09:53',
#                           'epoch_date_close_approach': 1031651580000,
#                           'miss_distance': {'astronomical': '0.4436836499',
#                                             'kilometers': '66374128.978865713',
#                                             'lunar': '172.5929398111',
#                                             'miles': '41242971.2854763194'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '67450.9784198508',
#                                                 'kilometers_per_second': '18.7363828944',
#                                                 'miles_per_hour': '41911.4148964901'}},
#                          {'close_approach_date': '2003-04-21',
#                           'close_approach_date_full': '2003-Apr-21 09:51',
#                           'epoch_date_close_approach': 1050918660000,
#                           'miss_distance': {'astronomical': '0.1781187203',
#                                             'kilometers': '26646181.164005761',
#                                             'lunar': '69.2881821967',
#                                             'miles': '16557169.2091750618'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55673.5342196243',
#                                                 'kilometers_per_second': '15.4648706166',
#                                                 'miles_per_hour': '34593.3690821882'}},
#                          {'close_approach_date': '2004-04-21',
#                           'close_approach_date_full': '2004-Apr-21 16:09',
#                           'epoch_date_close_approach': 1082563740000,
#                           'miss_distance': {'astronomical': '0.1191419731',
#                                             'kilometers': '17823385.403357297',
#                                             'lunar': '46.3462275359',
#                                             'miles': '11074938.1379408186'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63998.056907068',
#                                                 'kilometers_per_second': '17.7772380297',
#                                                 'miles_per_hour': '39765.9037487279'}},
#                          {'close_approach_date': '2005-04-17',
#                           'close_approach_date_full': '2005-Apr-17 01:58',
#                           'epoch_date_close_approach': 1113703080000,
#                           'miss_distance': {'astronomical': '0.3446815231',
#                                             'kilometers': '51563621.684115797',
#                                             'lunar': '134.0811124859',
#                                             'miles': '32040148.7930681186'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81940.0428884192',
#                                                 'kilometers_per_second': '22.7611230246',
#                                                 'miles_per_hour': '50914.3560936403'}},
#                          {'close_approach_date': '2020-12-01',
#                           'close_approach_date_full': '2020-Dec-01 01:43',
#                           'epoch_date_close_approach': 1606786980000,
#                           'miss_distance': {'astronomical': '0.4314824829',
#                                             'kilometers': '64548860.384151423',
#                                             'lunar': '167.8466858481',
#                                             'miles': '40108801.9728507174'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '88847.0399638397',
#                                                 'kilometers_per_second': '24.6797333233',
#                                                 'miles_per_hour': '55206.0954708647'}},
#                          {'close_approach_date': '2021-11-10',
#                           'close_approach_date_full': '2021-Nov-10 21:39',
#                           'epoch_date_close_approach': 1636580340000,
#                           'miss_distance': {'astronomical': '0.2483561844',
#                                             'kilometers': '37153556.187567228',
#                                             'lunar': '96.6105557316',
#                                             'miles': '23086149.2959866264'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '74738.7772156541',
#                                                 'kilometers_per_second': '20.7607714488',
#                                                 'miles_per_hour': '46439.7696538046'}},
#                          {'close_approach_date': '2022-10-19',
#                           'close_approach_date_full': '2022-Oct-19 00:15',
#                           'epoch_date_close_approach': 1666138500000,
#                           'miss_distance': {'astronomical': '0.2369525309',
#                                             'kilometers': '35447593.913749183',
#                                             'lunar': '92.1745345201',
#                                             'miles': '22026113.4935494054'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69028.1351248885',
#                                                 'kilometers_per_second': '19.1744819791',
#                                                 'miles_per_hour': '42891.3987391286'}},
#                          {'close_approach_date': '2023-04-07',
#                           'close_approach_date_full': '2023-Apr-07 01:18',
#                           'epoch_date_close_approach': 1680830280000,
#                           'miss_distance': {'astronomical': '0.4464563101',
#                                             'kilometers': '66788913.039019487',
#                                             'lunar': '173.6715046289',
#                                             'miles': '41500706.1491314406'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '56605.9807003187',
#                                                 'kilometers_per_second': '15.7238835279',
#                                                 'miles_per_hour': '35172.7550634841'}},
#                          {'close_approach_date': '2023-09-21',
#                           'close_approach_date_full': '2023-Sep-21 22:07',
#                           'epoch_date_close_approach': 1695334020000,
#                           'miss_distance': {'astronomical': '0.3873695712',
#                                             'kilometers': '57949662.754333344',
#                                             'lunar': '150.6867631968',
#                                             'miles': '36008250.7107703872'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68619.6762025846',
#                                                 'kilometers_per_second': '19.0610211674',
#                                                 'miles_per_hour': '42637.5982493226'}},
#                          {'close_approach_date': '2023-09-24',
#                           'close_approach_date_full': '2023-Sep-24 18:58',
#                           'epoch_date_close_approach': 1695581880000,
#                           'miss_distance': {'astronomical': '0.1009140677',
#                                             'kilometers': '15096529.580955799',
#                                             'lunar': '39.2555723353',
#                                             'miles': '9380548.4997920662'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '74150.037419661',
#                                                 'kilometers_per_second': '20.5972326166',
#                                                 'miles_per_hour': '46073.949640011'}},
#                          {'close_approach_date': '2024-04-18',
#                           'close_approach_date_full': '2024-Apr-18 13:07',
#                           'epoch_date_close_approach': 1713445620000,
#                           'miss_distance': {'astronomical': '0.2483576908',
#                                             'kilometers': '37153781.541798596',
#                                             'lunar': '96.6111417212',
# ...
#                           'epoch_date_close_approach': 4529723940000,
#                           'miss_distance': {'astronomical': '0.0425319415',
#                                             'kilometers': '6362687.855364605',
#                                             'lunar': '16.5449252435',
#                                             'miles': '3953590.902877349'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '67230.9725947463',
#                                                 'kilometers_per_second': '18.6752701652',
#                                                 'miles_per_hour': '41774.7118325522'}},
#                          {'close_approach_date': '2122-02-23',
#                           'close_approach_date_full': '2122-Feb-23 01:00',
#                           'epoch_date_close_approach': 4801251600000,
#                           'miss_distance': {'astronomical': '0.132878636',
#                                             'kilometers': '19878360.91410532',
#                                             'lunar': '51.689789404',
#                                             'miles': '12351840.709560616'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '65198.6036602679',
#                                                 'kilometers_per_second': '18.110723239',
#                                                 'miles_per_hour': '40511.876813237'}},
#                          {'close_approach_date': '2127-12-01',
#                           'close_approach_date_full': '2127-Dec-01 17:50',
#                           'epoch_date_close_approach': 4983357000000,
#                           'miss_distance': {'astronomical': '0.4157838836',
#                                             'kilometers': '62200383.366887932',
#                                             'lunar': '161.7399307204',
#                                             'miles': '38649526.0218481816'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '87487.642039154',
#                                                 'kilometers_per_second': '24.3021227887',
#                                                 'miles_per_hour': '54361.4184659399'}},
#                          {'close_approach_date': '2128-11-10',
#                           'close_approach_date_full': '2128-Nov-10 08:26',
#                           'epoch_date_close_approach': 5013131160000,
#                           'miss_distance': {'astronomical': '0.2398051704',
#                                             'kilometers': '35874342.706827048',
#                                             'lunar': '93.2842112856',
#                                             'miles': '22291282.8974993424'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '73994.3344437476',
#                                                 'kilometers_per_second': '20.5539817899',
#                                                 'miles_per_hour': '45977.2018658942'}},
#                          {'close_approach_date': '2130-04-09',
#                           'close_approach_date_full': '2130-Apr-09 11:02',
#                           'epoch_date_close_approach': 5057636520000,
#                           'miss_distance': {'astronomical': '0.4298004359',
#                                             'kilometers': '64297229.735711533',
#                                             'lunar': '167.1923695651',
#                                             'miles': '39952445.9382358354'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '56541.170511409',
#                                                 'kilometers_per_second': '15.7058806976',
#                                                 'miles_per_hour': '35132.4845324919'}},
#                          {'close_approach_date': '2131-04-21',
#                           'close_approach_date_full': '2131-Apr-21 06:12',
#                           'epoch_date_close_approach': 5090191920000,
#                           'miss_distance': {'astronomical': '0.2291863288',
#                                             'kilometers': '34285786.621599656',
#                                             'lunar': '89.1534819032',
#                                             'miles': '21304199.9177850128'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55250.3895024888',
#                                                 'kilometers_per_second': '15.3473304174',
#                                                 'miles_per_hour': '34330.4434105881'}},
#                          {'close_approach_date': '2132-04-23',
#                           'close_approach_date_full': '2132-Apr-23 11:46',
#                           'epoch_date_close_approach': 5122007160000,
#                           'miss_distance': {'astronomical': '0.089725772',
#                                             'kilometers': '13422784.37530564',
#                                             'lunar': '34.903325308',
#                                             'miles': '8340531.455232232'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '60928.913806196',
#                                                 'kilometers_per_second': '16.9246982795',
#                                                 'miles_per_hour': '37858.8575814111'}},
#                          {'close_approach_date': '2133-04-20',
#                           'close_approach_date_full': '2133-Apr-20 02:57',
#                           'epoch_date_close_approach': 5153252220000,
#                           'miss_distance': {'astronomical': '0.2869364306',
#                                             'kilometers': '42925078.843162822',
#                                             'lunar': '111.6182715034',
#                                             'miles': '26672407.1771860636'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '76924.0546575354',
#                                                 'kilometers_per_second': '21.3677929604',
#                                                 'miles_per_hour': '47797.616073178'}},
#                          {'close_approach_date': '2141-03-27',
#                           'close_approach_date_full': '2141-Mar-27 22:03',
#                           'epoch_date_close_approach': 5403708180000,
#                           'miss_distance': {'astronomical': '0.1155141388',
#                                             'kilometers': '17280669.119364356',
#                                             'lunar': '44.9349999932',
#                                             'miles': '10737709.8765498728'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '75364.2891939236',
#                                                 'kilometers_per_second': '20.9345247761',
#                                                 'miles_per_hour': '46828.4384716355'}},
#                          {'close_approach_date': '2148-12-07',
#                           'close_approach_date_full': '2148-Dec-07 06:04',
#                           'epoch_date_close_approach': 5646607440000,
#                           'miss_distance': {'astronomical': '0.4858283877',
#                                             'kilometers': '72678891.985454199',
#                                             'lunar': '188.9872428153',
#                                             'miles': '45160569.3563339862'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '93330.5630468404',
#                                                 'kilometers_per_second': '25.9251564019',
#                                                 'miles_per_hour': '57991.9823554103'}},
#                          {'close_approach_date': '2149-11-03',
#                           'close_approach_date_full': '2149-Nov-03 06:13',
#                           'epoch_date_close_approach': 5675206380000,
#                           'miss_distance': {'astronomical': '0.0366287139',
#                                             'kilometers': '5479577.580279393',
#                                             'lunar': '14.2485697071',
#                                             'miles': '3404851.6233179034'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '68108.4130923346',
#                                                 'kilometers_per_second': '18.9190036368',
#                                                 'miles_per_hour': '42319.9192350675'}},
#                          {'close_approach_date': '2149-11-17',
#                           'close_approach_date_full': '2149-Nov-17 14:33',
#                           'epoch_date_close_approach': 5676445980000,
#                           'miss_distance': {'astronomical': '0.285425531',
#                                             'kilometers': '42699051.48121897',
#                                             'lunar': '111.030531559',
#                                             'miles': '26531960.287082986'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77440.2121700161',
#                                                 'kilometers_per_second': '21.5111700472',
#                                                 'miles_per_hour': '48118.3362786414'}},
#                          {'close_approach_date': '2152-04-17',
#                           'close_approach_date_full': '2152-Apr-17 18:44',
#                           'epoch_date_close_approach': 5752665840000,
#                           'miss_distance': {'astronomical': '0.2969240882',
#                                             'kilometers': '44419211.146412134',
#                                             'lunar': '115.5034703098',
#                                             'miles': '27600817.9394460892'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55288.653475756',
#                                                 'kilometers_per_second': '15.3579592988',
#                                                 'miles_per_hour': '34354.2191555329'}},
#                          {'close_approach_date': '2153-04-23',
#                           'close_approach_date_full': '2153-Apr-23 16:40',
#                           'epoch_date_close_approach': 5784712800000,
#                           'miss_distance': {'astronomical': '0.1037943372',
#                                             'kilometers': '15527411.763181764',
#                                             'lunar': '40.3759971708',
#                                             'miles': '9648286.2726617832'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57887.1995124996',
#                                                 'kilometers_per_second': '16.0797776424',
#                                                 'miles_per_hour': '35968.8546081973'}},
#                          {'close_approach_date': '2154-04-22',
#                           'close_approach_date_full': '2154-Apr-22 06:18',
#                           'epoch_date_close_approach': 5816125080000,
#                           'miss_distance': {'astronomical': '0.2076215964',
#                                             'kilometers': '31059748.587439668',
#                                             'lunar': '80.7648009996',
#                                             'miles': '19299632.8363686984'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70528.7574896299',
#                                                 'kilometers_per_second': '19.5913215249',
#                                                 'miles_per_hour': '43823.8271190425'}},
#                          {'close_approach_date': '2155-04-16',
#                           'close_approach_date_full': '2155-Apr-16 05:37',
#                           'epoch_date_close_approach': 5847140220000,
#                           'miss_distance': {'astronomical': '0.4466980111',
#                                             'kilometers': '66825070.993796357',
#                                             'lunar': '173.7655263179',
#                                             'miles': '41523173.6603974466'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '91051.6261801345',
#                                                 'kilometers_per_second': '25.2921183834',
#                                                 'miles_per_hour': '56575.9396117619'}}],
#  'designation': '2024 FP2',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 1076.5272561075,
#                                  'estimated_diameter_min': 481.4376248575},
#                         'kilometers': {'estimated_diameter_max': 0.3281254972,
#                                        'estimated_diameter_min': 0.1467421834},
#                         'meters': {'estimated_diameter_max': 328.1254971615,
#                                    'estimated_diameter_min': 146.7421833608},
#                         'miles': {'estimated_diameter_max': 0.2038876683,
#                                   'estimated_diameter_min': 0.0911813372}},
#  'id': '54431700',
#  'is_potentially_hazardous_asteroid': False,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54431700?api_key=9FJ4JxFTJsq7dEB6zpPemkbnZlCdXZyh6XbTnfrG'},
#  'name': '(2024 FP2)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54431700',
#  'neo_reference_id': '54431700',
#  'orbital_data': {'aphelion_distance': '1.214967238011995',
#                   'ascending_node_longitude': '28.6970236036925',
#                   'data_arc_in_days': 58,
#                   'eccentricity': '.2524008576873916',
#                   'epoch_osculation': '2460600.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2024-03-21',
#                   'inclination': '31.10130372950555',
#                   'jupiter_tisserand_invariant': '6.079',
#                   'last_observation_date': '2024-05-18',
#                   'mean_anomaly': '62.2973249278478',
#                   'mean_motion': '1.031507185547447',
#                   'minimum_orbit_intersection': '.0872751',
#                   'observations_used': 61,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'similar to that '
#                                                              'of 2062 Aten',
#                                   'orbit_class_range': 'a (semi-major axis) < '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '> 0.983 AU',
#                                   'orbit_class_type': 'ATE'},
#                   'orbit_determination_date': '2024-05-18 06:19:01',
#                   'orbit_id': '12',
#                   'orbit_uncertainty': '5',
#                   'orbital_period': '349.0038703016293',
#                   'perihelion_argument': '313.5278858605549',
#                   'perihelion_distance': '.7252537871563858',
#                   'perihelion_time': '2460540.105534696508',
#                   'semi_major_axis': '.9701105125841906'}}

# %% [markdown]
# ## Exercise 1:  Define an Asteroid class
#
# Define a simple Asteroid class with some basic state variables for a single NEO.  Your Asteroid class should define at least 4 "state variables:”
#
#     id
#     name
#     estimated_diameter (m)
#     is_potentially_hazardous (bool)
#
# Operations must include:
# * `__init__(self, ...)` method to initialize a new Asteroid object with specific data values
# * `__str__(self)`, and `__repr__(self)` methods that return nicely formatted string representations of the object.
#
# Write a little code to test your new class.

# %%
# Ex.1 your code here
class Asteroid:
    def __init__(self, asteroid_id, name, estimated_diameter, is_potentially_hazardous):
        self.id = asteroid_id
        self.name = name
        self.estimated_diameter = estimated_diameter
        self.is_potentially_hazardous = is_potentially_hazardous

    def __str__(self):
        return (f"Asteroid:\n"
                f"  ID: {self.id}\n"
                f"  Name: {self.name}\n"
                f"  Estimated Diameter: {self.estimated_diameter:.2f} meters\n"
                f"  Potentially Hazardous: {'Yes' if self.is_potentially_hazardous else 'No'}")

    def __repr__(self):
        return (f"Asteroid(id='{self.id}', name='{self.name}', "
                f"estimated_diameter={self.estimated_diameter:.2f}, "
                f"is_potentially_hazardous={self.is_potentially_hazardous})")

neo1 = Asteroid(neo['id'], neo['name'], neo['estimated_diameter']['meters']['estimated_diameter_max'], neo['is_potentially_hazardous_asteroid'])
print(neo1)
print(repr(neo1))
# Out:
# Asteroid:
#   ID: 54431700
#   Name: (2024 FP2)
#   Estimated Diameter: 328.13 meters
#   Potentially Hazardous: No
# Asteroid(id='54431700', name='(2024 FP2)', estimated_diameter=328.13, is_potentially_hazardous=False)

# %% [markdown]
# ## Exercise 2: Make a histogram
#
# Create a list of all the Asteroid objects from this week's NEO feed and use the list to create a histogram to visualize the distribution of Asteroid diameters.  To create the historgram use the `hist()` method in the `matplotlib.pyplot` module.

# %%
# Ex. 2 your code here

asteroids = []
for neo in neos:
    asteroid = Asteroid(
        asteroid_id=neo['id'],
        name=neo['name'],
        estimated_diameter=neo['estimated_diameter']['meters']['estimated_diameter_max'],
        is_potentially_hazardous=neo['is_potentially_hazardous_asteroid']
    )
    asteroids.append(asteroid)

diameters = [asteroid.estimated_diameter for asteroid in asteroids]

plt.hist(diameters, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Asteroid Diameters')
plt.xlabel('Diameter (meters)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Exercise 3: Use `@dataclass` and `@classmethod` to do the same thing
#
# Now that you know how to define a simple class, we are going to use a use decorators to simplify (ie. shorten) our class definitions.  You will redefine the Asteroid class in this exercise.  Note that having two different definitions of a class in a single piece of code is very bad practice. I am asking you to do it here just so that you can see the differt ways to define classes.
#
#  1. Use the `@dataclass` decorator from the `dataclasses` module to define the Asteroid class.  The `@dataclass` decorator will automatically generate some of the commonly used methods, like `__init()__`, `__repr()__`, and `__eq()__`.  The definition should start like this:
#     ```
#     @dataclass
#     class Asteroid:
#       ...
#     ```
# Write a little code to test your new class.
#
#
#  2. Use the `@classmethod` decorator to construct a `from_NEO()` 'factory method' inside your Asteroid class that creates Asteroid objects from the NEO API.  The method should take the id for a single NEO, fetche the NEO record from API, constructs a single Asteroid object, and return the Asteroid object representing that NEO.  This kind of method is called a “Factory” because it constructs an object from raw materials.  The object factory method should start like this:
#     ```
#     @classmethod
#     from_NEO(cls, neo_id):
#         ...
#     ```
# Write a little code to test your new method.
#
#  3. Use your new Asteroid class to create a list of Asteroid objects.  Use this list to create the same historgram as in Exercise 2.

# %%
# Ex.3 your code here
@dataclass
class Asteroid:
    id: str
    name: str
    estimated_diameter: float
    is_potentially_hazardous: bool

    @classmethod
    def from_NEO(cls, neo_data):
        return cls(
            id=neo_data["id"],
            name=neo_data["name"],
            estimated_diameter=neo_data["estimated_diameter"]["meters"]["estimated_diameter_max"],
            is_potentially_hazardous=neo_data["is_potentially_hazardous_asteroid"]
        )

asteroids = [Asteroid.from_NEO(neo) for neo in neos]

diameters = [asteroid.estimated_diameter for asteroid in asteroids]

plt.hist(diameters, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Asteroid Diameters')
plt.xlabel('Diameter (meters)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Challenge Exercise:
#
# One of your esteemed astromoner collegues has a theory that there is a correlation between the diameter and the orbital period of an asteroid.  Add the `orbital_period` data from the NEO API to your Asteroid class definition and use it to plot the orbital period (in years) versus the estimated diameter (in m) of all the asteroids from this week's NEO record.  Do you see a correlation?

# %%
# Ex. Challenge your code here
@dataclass
class Asteroid:
    """A data class to represent an asteroid."""
    id: str
    name: str
    estimated_diameter: float
    is_potentially_hazardous: bool
    orbital_period: float

    @classmethod
    def from_NEO(cls, neo_data):
        orbital_period = None
        if 'orbital_data' in neo_data and 'orbital_period' in neo_data['orbital_data']:
            orbital_period = float(neo_data['orbital_data']['orbital_period']) / 365.25  # Convert days to years

        return cls(
            id=neo_data["id"],
            name=neo_data["name"],
            estimated_diameter=neo_data["estimated_diameter"]["meters"]["estimated_diameter_max"],
            is_potentially_hazardous=neo_data["is_potentially_hazardous_asteroid"],
            orbital_period=orbital_period
        )

def get_neo_details(asteroid_id):
    """Fetch detailed data for a single asteroid by its ID."""
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{asteroid_id}?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    return json.loads(response.text)

asteroids = []
for neo in neos:
    detailed_neo = get_neo_details(neo['id'])
    asteroid = Asteroid.from_NEO(detailed_neo)
    asteroids.append(asteroid)

diameters = [asteroid.estimated_diameter for asteroid in asteroids if asteroid.orbital_period is not None]
orbital_periods = [asteroid.orbital_period for asteroid in asteroids if asteroid.orbital_period is not None]

plt.scatter(diameters, orbital_periods, color='blue', alpha=0.7, edgecolor='black')
plt.title('Orbital Period vs. Estimated Diameter of Asteroids')
plt.xlabel('Estimated Diameter (m)')
plt.ylabel('Orbital Period (years)')
plt.grid(True)
plt.show()
